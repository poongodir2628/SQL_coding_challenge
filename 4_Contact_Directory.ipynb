# %% [markdown]
# Create a 2D list where each row holds a contact’s name, phone number, and email address.

# %%
contacts=[["divya","9036263058","divyaracks6636@gmail.com"],
          ["alahesh","9025356478","alahesh@gmail.com"],
          ["sinju","9845562598","sinju@gmail.com"]]
print(type(contacts))
print(contacts)
# Out:
# <class 'list'>
# [['divya', '9036263058', 'divyaracks6636@gmail.com'], ['alahesh', '9025356478', 'alahesh@gmail.com'], ['sinju', '9845562598', 'sinju@gmail.com']]

# %% [markdown]
# Allow the user to add a new contact.

# %%
name=input("Enter the name:")
phone_number=input("Enter the number:")
email=input("Enter the Email:")
# Out:
# Enter the name:pradiksan
# Enter the number:9896854555
# Enter the Email:pradik@gmail.com

# %%
contacts.append([name,phone_number,email])
print(contacts)
# Out:
# [['divya', '9036263058', 'divyaracks6636@gmail.com'], ['alahesh', '9025356478', 'alahesh@gmail.com'], ['sinju', '9845562598', 'sinju@gmail.com'], ['pradiksan', '9896854555', 'pradik@gmail.com']]

# %% [markdown]
# Display all contacts sorted alphabetically by name.

# %%
contacts.sort()
print(contacts)
# Out:
# [['alahesh', '9025356478', 'alahesh@gmail.com'], ['divya', '9036263058', 'divyaracks6636@gmail.com'], ['pradiksan', '9896854555', 'pradik@gmail.com'], ['sinju', '9845562598', 'sinju@gmail.com']]

# %% [markdown]
# Allow the user to search for contacts by name. The search should support partial matches.

# %%
name1=input("Enter the name:")
for i in contacts:
  if name1 in i:
    print(i)
# Out:
# Enter the value:sinju
# ['sinju', '9845562598', 'sinju@gmail.com']

# %% [markdown]
# After sorting, display only the first 3 contacts in the list.

# %%
print(contacts[0:3])
# Out:
# [['alahesh', '9025356478', 'alahesh@gmail.com'], ['divya', '9036263058', 'divyaracks6636@gmail.com'], ['pradiksan', '9896854555', 'pradik@gmail.com']]
