# %% [markdown]
# Create profile

# %%
student_name="Siranjith"
student_age=15
favourite_subject=["maths","english","science"]
print("Name:",student_name)
print("Age:",student_age)
print("Subject:",favourite_subject)
# Out:
# Name: Siranjith
# Age: 15
# Subject: ['maths', 'english', 'science']

# %% [markdown]
# Ask the student to enter their favourite subjecT

# %%
new_favourite_subject=input("Enter the favourite subject:")
# Out:
# Enter the favourite subject:social

# %% [markdown]
# Add it to their favourite subjects variable

# %%
favourite_subject.append(new_favourite_subject)

# %% [markdown]
# Display the updated list of subjects

# %%
print("Name:",student_name)
print("Age:",student_age)
print("Subject:",favourite_subject)
# Out:
# Name: Siranjith
# Age: 15
# Subject: ['maths', 'english', 'science', 'social']
