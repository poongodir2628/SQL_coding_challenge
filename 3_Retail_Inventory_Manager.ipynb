# %% [markdown]
# Create a tuple

# %%
Tuple_Product=("Electronics", "Stationery","Clothing")
print("Fixed product catagories:",Tuple_Product)
# Out:
# Fixed product catagories: ('Electronics', 'Stationery', 'Clothing')

# %% [markdown]
# Create a list

# %%
list_Product=["Mobile","Appliances","Fashion"]
print(list_Product)
# Out:
# ['Mobile', 'Appliances', 'Fashion']

# %% [markdown]
# Ask the user to enter a new product and add it to the list.

# %%
new_product="wood"
print(new_product)
# Out:
# wood

# %%
list_Product.append(new_product)
print(list_Product)
# Out:
# ['Mobile', 'Appliances', 'Fashion', 'Furniture', 'wood']

# %% [markdown]
# Ask the user to input the index of a product to remove it from the list

# %%
index=int(input("Enter the index of product:"))
# Out:
# Enter the index of product:3

# %%
removed_index=list_Product.pop(index)
print(removed_index)
# Out:
# Furniture

# %%
print(Tuple_Product)
print(removed_index)
print(list_Product)
# Out:
# ('Electronics', 'Stationery', 'Clothing')
# Furniture
# ['Mobile', 'Appliances', 'Fashion', 'wood']
