# %% [markdown]
# Ask the user to input a sentence

# %%
feedback=input("Enter your feedback:")
# Out:
# Enter your feedback:I would like to recommand everyone to learn Data Analyst course in Entri App.

# %% [markdown]
# Count how many words are in the sentence.

# %%
words="Python is a programming language,it is easy to learn Python"
print("Total words:",len(words))
# Out:
# Total words: 59

# %% [markdown]
# Check how many times the word “data” appears in the sentence

# %%
count=words.count("Python")
print("count of words:",count)
# Out:
# count of words: 2

# %% [markdown]
# Extract and print the first 5 and last 5 characters of the feedback separately.

# %%
first_5=feedback[0:5]
print("first_5 caharacter:",first_5)
# Out:
# first_5 caharacter: I wou

# %%
last_5=feedback[-5:]
print("last_5 caharcter:",last_5)
# Out:
# last_5 caharcter:  App.

# %% [markdown]
# Reverse the sentence and print it

# %%
rev=feedback[::-1]
print("reversed feedback:",rev)
# Out:
# reversed feedback: .ppA irtnE ni esruoc tsylanA ataD nrael ot enoyreve dnammocer ot ekil dluow I
